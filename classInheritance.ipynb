# %%
class battery():
  def __init__(self,amp,plate,manuf):
    self.amp=amp
    self.plate=plate
    self.manuf=manuf
  def get_amp(self):
    return self.amp

# %%
class car():
   def __init__(self,make,model,year):
     self.make=make
     self.model=model
     self.year=year
     self.odometer=0
  
   def get_descriptive_name(self):
     long_name=str(self.make)+" "+str(self.model)+" "+str(self.year)
     return long_name.title()
   def Set_odometer(self,mileage):
     self.mileage=int(input("Enter Mileage"))
     self.odometer_reading=mileage

   def get_odometer(self):
      print("this car has "+str(self.odometer_reading)+" Miles on it")

# %%
class Electricalcar(car):
  def __init__(self,make,model,year):
    super().__init__(make,model,year)

    self.battery=battery("225amp",27,"osaka")
  def describe_car(self):
    print(self.make,self.model,self.year,self.battery.get_amp())

# %%
my_tesla.battery.get_amp()
# Out:
# '225amp'

# %%
my_tesla=Electricalcar("tesla","model S",2016)

print(my_tesla.describe_car())
# Out:
# tesla model S 2016 225amp
# None

# %%
my_tesla2=Electricalcar("tesla","model S",2016)
print(my_tesla2.describe_car())
# Out:
# model S tesla 2016 <__main__.battery object at 0x7f8d605fc390>
# None
