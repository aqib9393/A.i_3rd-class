# %%
class Restaurant():
  def __init__(self,restaurantName,cusineType):
    self.restaurantName=restaurantName
    self.cusineType=cusineType

  def decribe_restaurant(self):
    print(f"Restaurant Name : {self.restaurantName} And CusineType is : {self.cusineType} ")

  def Open_restaurent(self):
    print("   !Restaurent Oopen!   ")

# %%
rest=Restaurant("Royal_Red ","Ice-cream")

# %%
rest.restaurantName
# Out:
# 'Royal_Red '

# %%
rest.decribe_restaurant()
# Out:
# Restaurant Name : Royal_Red  And CusineType is : Ice-cream

# %%
restaurant1=Restaurant("Red Apple "," Tikka ")

# %%
restaurant2=Restaurant("Crescent "," Malai")

# %%
restaurant3=Restaurant("Kabab-jee "," Sheesha! ")

# %%
print(restaurant1.decribe_restaurant(),restaurant1.Open_restaurent() )
print(restaurant2.decribe_restaurant(),restaurant2.Open_restaurent() )
print(restaurant3.decribe_restaurant(),restaurant3.Open_restaurent() )
# Out:
# Restaurant Name : Red Apple  And CusineType is :  Tikka
#    !Restaurent Oopen!
# None None
# Restaurant Name : Crescent  And CusineType is :  Malai
#    !Restaurent Oopen!
# None None
# Restaurant Name : Kabab-jee  And CusineType is :  Sheesha!
#    !Restaurent Oopen!
# None None

# %%
class user():
  def __init__(self,firstName,lastName):
