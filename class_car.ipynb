# %%
class car():
   def __init__(self,make,model,year):
     self.make=make
     self.model=model
     self.year=year
     self.odometer=0
  
   def get_descriptive_name(self):
     long_name=str(self.make)+" "+str(self.model)+" "+str(self.year)
     return long_name.title()
   def Set_odometer(self,mileage):
     self.mileage=int(input("Enter Mileage"))
     self.odometer_reading=mileage

   def get_odometer(self):
      print("this car has "+str(self.odometer_reading)+" Miles on it")

# %%
car1=car("Honda","Civic",2021)
car1.get_descriptive_name()
# Out:
# 'Honda Civic 2021'

# %%
car1.Set_odometer(mileage=input("enter"))
# Out:
# enter90
# Enter Mileage50

# %%
car1.get_descriptive_name()
car1.get_odometer()
# Out:
# this car has 90 Miles on it

# %%
class Electricalcar(car):
  def __init(self,make,model,year):
    super.__init__(make,model,year)

# %%
mytesla=Electricalcar("Kia","Sportage",2020)

# %%
print(mytesla.get_descriptive_name())
# Out:
# Kia Sportage 2020
